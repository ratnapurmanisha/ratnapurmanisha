# %%
import sklearn,seaborn as sns 
import matplotlib.pyplot as plt

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isna().sum()# checking how many missing values available in the dataframe
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
(688/890)*100 # missing values percentage checking  of 'deck' colomn with total dataframe
# Out:
# 77.30337078651685

# %%
(177/890)*100#missing values percentage checking  of 'age' colomn with total dataframe
# Out:
# 19.8876404494382

# %%
#  Here,The 'deck' column is removing from df1 using the drop method
# and considering  axis=1 to indicate a column operation.
df1 = df.drop('deck',axis = 1)

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df1.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ### Uni and Bi variant analysis (both non - visualization & visualization methods)

# %% [markdown]
# ### Univariate Visualization

# %% [markdown]
# * it refers to the visualization of a single variable. Univariate analysis involves examining the distribution and characteristics of a single variable, without considering relationships with other variables.

# %%
sns.histplot(df1,x = 'age',color = 'purple')# The code will create a histogram plot of the 'age' column in the DataFrame 'df1'.
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Creating a histogram plot of the 'fare' column in the DataFrame 'df1' using seaborn library
# The x-axis represents the 'fare' values.
sns.histplot(df1,x = 'fare',color ='purple')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %% [markdown]
# * there are max values around 0-60 ,
# * there are least values b/w 60-80,
# * there is only one value above 100 i.e 500.

# %%
sns.histplot(df1,x = 'pclass',color ='purple')
# Out:
# <Axes: xlabel='pclass', ylabel='Count'>

# %%
sns.histplot(df1, x = 'sex',color= 'purple')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.histplot(df1,x ='survived',color= 'purple')
# Out:
# <Axes: xlabel='survived', ylabel='Count'>

# %%
sns.histplot(df1,x = 'embarked',color= 'purple')
# Out:
# <Axes: xlabel='embarked', ylabel='Count'>

# %% [markdown]
# ### Bivariate

# %%
#This plot counts the occurrences of each combination of 'survived' and 'sex'.
sns.countplot(x= 'survived',hue = 'sex',data = df1,color= 'purple')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x ='survived', hue ='embarked', data = df1,color= 'purple')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x ='survived', hue ='pclass', data = df1,color= 'purple')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# ### Handle Missing Values In Age col

# %%
df1, df2 = df.copy(), df.copy()

# %%
sns.distplot(df['age'], kde = True, hist = True, bins = 20,color= 'purple')
#visualization on age colomn by imputing median values using distplot
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['age'].fillna(df['age'].median()), kde = True, hist = True, bins = 20,color= 'purple')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# * before imputing missing values in age column

# %%
df['age'].fillna(df['age'].median())# non _visualization on age colomn by imputing median values
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
sns.distplot(df['age'].fillna(df['age'].median()), kde = True, hist = True, bins = 20,color= 'purple')
#visualization on age colomn by imputing median values using distplot
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# * After imputing missing values with median the data is not asa same as before imputing missing values

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
sns.distplot(df['age'].fillna(df['age'].mean()), kde = True, hist = True, bins = 20)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df.groupby(['embarked'])['age'].transform(lambda x : x.fillna(x.median())), kde = True, hist = True, bins = 20,color= 'purple')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['age'].ffill().bfill(), kde = True, hist = True, bins = 20,color= 'purple')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['age'].fillna(df['age'].mode()), kde = True, hist = True, bins = 20,color= 'darkgreen')# after imputation with mode
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.distplot(df['age'], kde = True, hist = True, bins = 20,color = 'purple')# before imputation
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# * finally conclude that by imputing missing values in age column with mode the visualization were same before and after impution

# %%
df['embarked']=df['embarked'].fillna(df['embarked'].mode())

# %% [markdown]
# ### Identifing and handling outliers in fare with appropriate techniques

# %%
sns.boxplot(df['fare'])
# Out:
# <Axes: >

# %%
def luFence(x):# function for inter quartile range
    #x = x.sort()
    iqr = x.quantile(0.75) - x.quantile(0.25)
    lowerFence, upperFence = max(min(x), x.quantile(0.25)-1.5*iqr), min(max(x), x.quantile(0.75)+1.5*iqr)
    return lowerFence, upperFence

# %%
luFence(df['fare'])
# Out:
# (0.0, 65.6344)

# %%
outliers = (df['fare'] < 0.0) | (df['fare'] > 65.6344)

# %% [markdown]
# ### imputing missing values with mode in 'Fare' column

# %%
fare_mode = df['fare'].mode()
df.loc[outliers, 'fare'] = fare_mode

print("Number of outliers replaced:", outliers.sum())
# Out:
# Number of outliers replaced: 116

# %%
df['clipped_data_of_fare'] = df['fare'].clip(lower = 0.0, upper = 65.6344)
sns.boxplot(x='clipped_data_of_fare', data=df)
# Out:
# <Axes: xlabel='clipped_data_of_fare'>

# %% [markdown]
# ### imputing missing values with median in 'Fare' column

# %%
fare_median = df['fare'].median()
df.loc[outliers, 'fare'] = fare_median

print("Number of outliers replaced:", outliers.sum())
# Out:
# Number of outliers replaced: 116

# %% [markdown]
# ### imputing missing values with mode in 'Fare' column¶

# %%
fare_mean = df['fare'].mean()
df.loc[outliers, 'fare'] = fare_mean

print("Number of outliers replaced:", outliers.sum())
# Out:
# Number of outliers replaced: 116

# %% [markdown]
# * finally concluded that Imputing Fare values is the appropriate method for cleaing Outliers

# %%
sns.histplot(df1,x = 'fare',color ='purple',kde = True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
df['clipped_data_of_fare'] = df['fare'].clip(lower = 0.0, upper = 65.6344)
sns.histplot(x='clipped_data_of_fare', data=df,kde = True)
# Out:
# <Axes: xlabel='clipped_data_of_fare', ylabel='Count'>

# %% [markdown]
# * The data is Now in Normal, becuase their is no values present beyond upper limit
